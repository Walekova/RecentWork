# %%
import requests

# %%
response = requests.get("http://dataservice.accuweather.com/locations/v1/topcities/150?apikey=9vvRWrL3ioBZFzTcuXg1QPZz0f1Xssu0")
print(response)
# Out:
# <Response [200]>

# %%
import json

def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(response.json())
# Out:
# [
#     {
#         "AdministrativeArea": {
#             "CountryID": "BD",
#             "EnglishName": "Dhaka",
#             "EnglishType": "Division",
#             "ID": "C",
#             "Level": 1,
#             "LocalizedName": "Dhaka",
#             "LocalizedType": "Division"
#         },
#         "Country": {
#             "EnglishName": "Bangladesh",
#             "ID": "BD",
#             "LocalizedName": "Bangladesh"
#         },
#         "DataSets": [],
#         "EnglishName": "Dhaka",
#         "GeoPosition": {
#             "Elevation": {
#                 "Imperial": {
#                     "Unit": "ft",
#                     "UnitType": 0,
#                     "Value": 16.0
#                 },
#                 "Metric": {
#                     "Unit": "m",
#                     "UnitType": 5,
#                     "Value": 5.0
#                 }
#             },
#             "Latitude": 23.71,
#             "Longitude": 90.407
#         },
# ...

# %%
response = requests.get("http://dataservice.accuweather.com/currentconditions/v1/28143?apikey=9vvRWrL3ioBZFzTcuXg1QPZz0f1Xssu0")
print(response)
# Out:
# <Response [200]>

# %%
jprint(response.json())
# Out:
# [
#     {
#         "EpochTime": 1572797100,
#         "HasPrecipitation": false,
#         "IsDayTime": false,
#         "Link": "http://www.accuweather.com/en/bd/dhaka/28143/current-weather/28143?lang=en-us",
#         "LocalObservationDateTime": "2019-11-03T22:05:00+06:00",
#         "MobileLink": "http://m.accuweather.com/en/bd/dhaka/28143/current-weather/28143?lang=en-us",
#         "PrecipitationType": null,
#         "Temperature": {
#             "Imperial": {
#                 "Unit": "F",
#                 "UnitType": 18,
#                 "Value": 77.0
#             },
#             "Metric": {
#                 "Unit": "C",
#                 "UnitType": 17,
#                 "Value": 25.0
#             }
#         },
#         "WeatherIcon": 35,
#         "WeatherText": "Partly cloudy"
#     }
# ]

# %%
response = requests.get("http://dataservice.accuweather.com/currentconditions/v1/topcities/150?apikey=9vvRWrL3ioBZFzTcuXg1QPZz0f1Xssu0")
print(response)
# Out:
# <Response [200]>

# %%
jprint(response.json())
# Out:
# [
#     {
#         "Country": {
#             "EnglishName": "Bangladesh",
#             "ID": "BD",
#             "LocalizedName": "Bangladesh"
#         },
#         "EnglishName": "Dhaka",
#         "EpochTime": 1572796860,
#         "GeoPosition": {
#             "Elevation": {
#                 "Imperial": {
#                     "Unit": "ft",
#                     "UnitType": 0,
#                     "Value": 16.0
#                 },
#                 "Metric": {
#                     "Unit": "m",
#                     "UnitType": 5,
#                     "Value": 5.0
#                 }
#             },
#             "Latitude": 23.7098,
#             "Longitude": 90.40711
#         },
#         "HasPrecipitation": false,
#         "IsDayTime": false,
#         "Key": "28143",
#         "Link": "http://www.accuweather.com/en/bd/dhaka/28143/current-weather/28143?lang=en-us",
#         "LocalObservationDateTime": "2019-11-03T22:01:00+06:00",
# ...

# %%
response = requests.get("http://dataservice.accuweather.com/imagery/v1/maps/radsat/1024x1024/28143?apikey=SnUPrdKxuZcUsSzXWDl5cae481d5hqNA")
print(response)
# Out:
# <Response [200]>

# %%
jprint(response.json())
# Out:
# {
#     "Link": "http://www.accuweather.com/en/bd/national/satellite?lang=en-us",
#     "MobileLink": "http://m.accuweather.com/en/bd/national/satellite?lang=en-us",
#     "Satellite": {
#         "Images": [
#             {
#                 "Date": "2019-11-03T20:48:00+06:00",
#                 "Url": "http://vortex.accuweather.com/adc2004/mapspace/world_ir/1024x1024/INDIA_1911031448.png"
#             },
#             {
#                 "Date": "2019-11-03T21:01:00+06:00",
#                 "Url": "http://vortex.accuweather.com/adc2004/mapspace/world_ir/1024x1024/INDIA_1911031501.png"
#             },
#             {
#                 "Date": "2019-11-03T21:32:00+06:00",
#                 "Url": "http://vortex.accuweather.com/adc2004/mapspace/world_ir/1024x1024/INDIA_1911031532.png"
#             },
#             {
#                 "Date": "2019-11-03T21:45:00+06:00",
# ...

# %%
response = requests.get("https://tilecache.rainviewer.com/v2//radar/1572792000/512/20/40.779/-73.969/2/0_0.png")
print(response)
# Out:
# <Response [200]>
