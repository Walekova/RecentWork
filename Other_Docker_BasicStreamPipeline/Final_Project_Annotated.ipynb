# %% [markdown]
# # W205 Project 3
# ### Andy Cui, Ivan Fan, Miroslava Walekova

# %% [markdown]
# ### Introduction

# %% [markdown]
# In this project, we are working as data scientists for a gaming company focused on understanding the revenue streams and game retention for our newest game. There are two major actions that players can use to interact with our game financially: they can (1) add money to their accounts, after which they can (2) purchase in game items. There are also two major events that users can take on the social site, they can (1) join a guild to network with other players, and (2) cancel or leave the guild if they are unhappy. We've set up our pipeline to stream in data from the game api into our data pipeline, and are able to issue queries on these pieces of data to better understand our users and drive business decisions.

# %% [markdown]
# ### Tasks and Setup

# %% [markdown]
# Below is a list of commands that we ran to set up our data collection pipeline for our game.

# %%
# !cat walekova_annotations.md
# Out:
# # My annotations, Project 3
#
# ## New window (1) - Navigating to w205 directory
# cd w205/
#
# ## Window (1) - Creating full-stack2 directory
# mkdir full-stack2
#
# ## Window (1) - Next, I'm checking what's in my directory
# ls
#
# ## Window (1) - Navigate to my new full-stack2 directory
# cd full-stack2
#
# ## Window (1) - Looking at the docker-compose file to check content
# cat docker-compose.yml
#
# ## Window (1) - Quick Sanity Check
# docker-compose ps
#
# ## Window (1) - Spinning up my kafka, zookeeper, mids, cloudera/hadoop cluster.
# docker-compose up -d
#
# ## Window (1) - Quick Sanity Check
# docker-compose ps
#
# ## Window (1) - Check whether the binding succeeded
# docker-compose logs zookeeper | grep -i binding
#
# ## Window (1) - Check that the right kafka components have started
# docker-compose logs kafka | grep -i started
#
# ## Window (1) - Checking out Hadoop
# docker-compose exec cloudera hadoop fs -ls /tmp/
#
# ## Window (1) - Bring Flask Up
# docker-compose exec mids env FLASK_APP=/w205/full-stack2/game_api.py flask run --host 0.0.0.0
#
# ## Window (1) - Create a topic 'game_events'
# docker-compose exec kafka kafka-topics --create --topic game_events --partitions 1 --replication-factor 1 --if-not-exists --zookeeper zookeeper:32181
#
# ## Window (1) - Check the topic
# docker-compose exec kafka kafka-topics --describe --topic game_events --zookeeper zookeeper:32181
#
# ## New window (2) - Running kafkacat continuously
# docker-compose exec mids kafkacat -C -b kafka:29092 -t game_events -o beginning
#
# ## New window (3) - write purchase events using Spark
# docker-compose exec spark spark-submit /w205/full-stack2/write_stream.py
#
# ## New window (4) - Generating events using Apache bench
# docker-compose exec mids ab -n 10 -H "Host: localhost" http://localhost:5000/
# docker-compose exec mids ab -n 10 -H "Host: localhost" http://localhost:5000/purchase_a_sword=Default%20Sword
# docker-compose exec mids ab -n 10 -H "Host: localhost" http://localhost:5000/add_money_to_account?amount=5
# docker-compose exec mids ab -n 10 -H "Host: localhost" http://localhost:5000/add_money_to_account?amount=10
# docker-compose exec mids ab -n 1 -H "Host: oski.berkeley.edu" http://localhost:5000/
# docker-compose exec mids ab -n 2 -H "Host: oski.berkeley.edu" http://localhost:5000/purchase_a_sword?sword_type=Great%20Sword
# docker-compose exec mids ab -n 15 -H "Host: oski.berkeley.edu" http://localhost:5000/purchase_a_knife?sword_type=Deadly%20Dagger
# docker-compose exec mids ab -n 100 -H "Host: oski.berkeley.edu" http://localhost:5000/add_money_to_account?amount=100
# docker-compose exec mids ab -n 10 -H "Host: tree.stanfurd.edu" http://localhost:5000/
# docker-compose exec mids ab -n 1 -H "Host: tree.stanfurd.edu" http://localhost:5000/add_money_to_account?amount=1
# docker-compose exec mids ab -n 1 -H "Host: tree.stanford.edu" http://localhost:5000/join_guild?guild_name=stanford
# docker-compose exec mids ab -n 1 -H "Host: berkeley.edu" http://localhost:5000/join_guild?guild_name=berkeley
# docker-compose exec mids ab -n 1 -H "Host: tree.stanford.edu" http://localhost:5000/cancel_membership?reason=BooHoo
# docker-compose exec mids ab -n 1 -H "Host: admin.admin" http://localhost:5000/message?msg=No%20Cheating!
#
# ## New window (5) - check the folder and parquet file have been created
# docker-compose exec cloudera hadoop fs -ls /tmp/
#
# ## New window (6) - Spin up a notebook
# docker-compose exec spark env PYSPARK_DRIVER_PYTHON=jupyter PYSPARK_DRIVER_PYTHON_OPTS='notebook --no-browser --port 8888 --ip 0.0.0.0 --allow-root' pyspark
#
# ## Chrome Browser - enter ip and token
# http://35.246.74.247:8888
#
# ## Chrome Browser - Play in Jupyter Notebook
# #### Analyse Purchases, Money addition, Transactions, Memberships, Cancellations, Messaging
#
# ## POST
# docker-compose exec mids curl http://localhost:5000/message?message_post=this%20is%20a%20GET%20message
# docker-compose exec mids curl --data "message_post=this is a POST message - booyah!" http://localhost:5000/message
#
# ## Chrome Browser - Play in Jupyter Notebook
# #### Display messages

# %% [markdown]
# ##### game_api.py
# Our game api has major changes. We added the purchasing of a knife, as well as descriptions for both of these types of purchases. In addition, we added a way for users to add money to their accounts. They can do this by querying the api with the amount parameter set. We also allow for users to join guilds and cancel their memberships in such guilds. Finally, we allow users to post message to the shared message board.

# %%
! cat game_api.py
# Out:
# #!/usr/bin/env python
# import json
# from kafka import KafkaProducer
# from flask import Flask, request
#
# app = Flask(__name__)
# producer = KafkaProducer(bootstrap_servers='kafka:29092')
#
#
# def log_to_kafka(topic, event):
#     event.update(request.headers)
#     producer.send(topic, json.dumps(event).encode())
#
#
# @app.route("/")
# def default_response():
#     default_event = {'event_type': 'default'}
#     log_to_kafka('game_events', default_event)
#     return "This is the default response!\n"
#
# @app.route("/purchase_a_sword")
# def purchase_a_sword():
#     sword_type = str(request.args.get('sword_type'))
#     purchase_sword_event = {'event_type': 'purchase_sword',
#                             'description': sword_type,
#                              'amount': '-10'}
#     log_to_kafka('game_events', purchase_sword_event)
#     return "Sword Purchased!\n"
#
# @app.route("/purchase_a_knife")
# def purchase_a_knife():
#     knife_type = str(request.args.get('knife_type'))
#     purchase_knife_event = {'event_type': 'purchase_knife',
#                             'description': knife_type ,
#                             'amount': '-10'}
#     log_to_kafka('game_events', purchase_knife_event)
#     return "Knife Purchased!\n"
#
# @app.route("/add_money_to_account")
# def add_money_to_account():
#     amount = str(request.args.get('amount'))
#     add_money_to_account_event = {'event_type': 'add_money',
#                                   'description': 'money',
#                                   'amount': amount}
#     log_to_kafka('game_events', add_money_to_account_event)
#     return "Money added to account!\n"
#
#
# @app.route("/join_guild")
# def join_guild():
#     guild_name = str(request.args.get('guild_name'))
#     join_guild_event = {'event_type': 'join_guild',
#                                    'guild_name': guild_name}
#     log_to_kafka('game_events', join_guild_event)
#     return "Guild Joined"
#
#
# @app.route("/cancel_membership")
# def cancel_membership():
#     cancel_reason = str(request.args.get('cancel_reason'))
#     cancel_membership_event = {'event_type': 'cancel_membership',
#                                    'cancel_reason': cancel_reason}
#     log_to_kafka('game_events', cancel_membership_event)
#     return "Membership Cancelled"
#
# @app.route("/message", methods = ['GET', 'POST'])
# def message():
#     if request.method == 'GET':
#         mensaje = str(request.args.get('message_post'))
#         message_event = {'event_type': 'mensaje',
#                        'message_post': mensaje}
#         log_to_kafka('game_events', message_event)
#         return "Message sent"
#     elif request.method == 'POST':
#         mensaje = str(request.form.get('message_post'))
#         message_event = {'event_type': 'mensaje',
#                        'message_post': mensaje}
#         log_to_kafka('game_events', message_event)
#         return "Message sent"

# %% [markdown]
# ##### write_stream.py
# This is our major spark streaming job. Every two minutes, we will filter out all the purchase, add money, guild related, and messaging events, decorate them with some request header information like host name, and write them out to HDFS. Each type of event is written into separate loactions because they have different schemas.

# %%
! cat write_stream.py
# Out:
# #!/usr/bin/env python
# """Extract events from kafka and write them to hdfs
# """
# import json
# from pyspark.sql import SparkSession
# from pyspark.sql.functions import udf, from_json
# from pyspark.sql.types import StructType, StructField, StringType
#
#
# def transaction_event_schema():
#     """
#     root
#     |-- Accept: string (nullable = true)
#     |-- Host: string (nullable = true)
#     |-- User-Agent: string (nullable = true)
#     |-- event_type: string (nullable = true)
#     |-- description: string (nullable = true)
#     |-- amount: string (nullable = true)
#     |-- timestamp: string (nullable = true)
#     """
#     return StructType([
#         StructField("Accept", StringType(), True),
#         StructField("Host", StringType(), True),
#         StructField("User-Agent", StringType(), True),
#         StructField("event_type", StringType(), True),
#         StructField("amount", StringType(), True),
#         StructField("description", StringType(), True),
#     ])
#
#
# def purchase_event_schema():
#     return transaction_event_schema()
#
# def add_money_event_schema():
#     return transaction_event_schema()
#
# def guild_membership_event_schema():
#     """
#     root
#     |-- Accept: string (nullable = true)
#     |-- Host: string (nullable = true)
#     |-- User-Agent: string (nullable = true)
#     |-- event_type: string (nullable = true)
#     |-- guild_name: string (nullable = true)
#     |-- timestamp: string (nullable = true)
#     """
#     return StructType([
#         StructField("Accept", StringType(), True),
#         StructField("Host", StringType(), True),
#         StructField("User-Agent", StringType(), True),
#         StructField("event_type", StringType(), True),
#         StructField("guild_name", StringType(), True),
#     ])
#
# def cancel_membership_event_schema():
#     """
#     root
#     |-- Accept: string (nullable = true)
#     |-- Host: string (nullable = true)
#     |-- User-Agent: string (nullable = true)
#     |-- event_type: string (nullable = true)
#     |-- cancel_reason: string (nullable = true)
#     |-- timestamp: string (nullable = true)
#     """
#     return StructType([
#         StructField("Accept", StringType(), True),
#         StructField("Host", StringType(), True),
#         StructField("User-Agent", StringType(), True),
#         StructField("event_type", StringType(), True),
#         StructField("cancel_reason", StringType(), True),
#     ])
#
# def message_event_schema():
#     """
#     root
#     |-- Accept: string (nullable = true)
#     |-- Host: string (nullable = true)
#     |-- User-Agent: string (nullable = true)
#     |-- event_type: string (nullable = true)
#     |-- message: string (nullable = true)
#     |-- timestamp: string (nullable = true)
#     """
#     return StructType([
#         StructField("Accept", StringType(), True),
#         StructField("Host", StringType(), True),
#         StructField("User-Agent", StringType(), True),
#         StructField("event_type", StringType(), True),
#         StructField("message_post", StringType(), True),
#     ])
#
# @udf('boolean')
# def is_purchase(event_as_json):
#     """udf for filtering events
#     """
#     event = json.loads(event_as_json)
#     if 'purchase' in event['event_type']:
#         return True
#     return False
#
# @udf('boolean')
# def is_add_money(event_as_json):
#     """udf for filtering events
#     """
#     event = json.loads(event_as_json)
#     if event['event_type'] == 'add_money':
#         return True
#     return False
#
# @udf('boolean')
# def is_transaction(event_as_json):
#     """udf for filtering events
#     """
#     event = json.loads(event_as_json)
#     if event['event_type'] == 'add_money' or 'purchase' in event['event_type']:
#         return True
#     return False
#
#
# @udf('boolean')
# def is_join_guild(event_as_json):
#     """udf for filtering events
#     """
#     event = json.loads(event_as_json)
#     if event['event_type'] == 'join_guild':
#         return True
#     return False
#
# @udf('boolean')
# def is_guild_member(event_as_json):
#     """udf for filtering events
#     """
#     event = json.loads(event_as_json)
#     if event['event_type'] == 'join_guild':
#         return True
#     return False
#
# @udf('boolean')
# def is_cancel_member(event_as_json):
#     """udf for filtering events
#     """
#     event = json.loads(event_as_json)
#     if event['event_type'] == 'cancel_membership':
#         return True
#     return False
#
# @udf('boolean')
# def is_message(event_as_json):
#     """udf for filtering events
#     """
#     event = json.loads(event_as_json)
#     if event['event_type'] == 'mensaje':
#         return True
#     return False
#
#
# def main():
#     """
#     main
#     """
#     spark = SparkSession \
#         .builder \
#         .appName("ExtractEventsJob") \
#         .getOrCreate()
#
#     raw_events = spark \
#         .readStream \
#         .format("kafka") \
#         .option("kafka.bootstrap.servers", "kafka:29092") \
#         .option("subscribe", "game_events") \
#         .load()
#
#     purchases = raw_events \
#         .filter(is_purchase(raw_events.value.cast('string'))) \
#         .select(raw_events.value.cast('string').alias('raw_event'),
#                 raw_events.timestamp.cast('string'),
#                 from_json(raw_events.value.cast('string'),
#                           purchase_event_schema()).alias('json')) \
#         .select('raw_event', 'timestamp', 'json.*')
#
#     add_money = raw_events \
#         .filter(is_add_money(raw_events.value.cast('string'))) \
#         .select(raw_events.value.cast('string').alias('raw_event'),
#                 raw_events.timestamp.cast('string'),
#                 from_json(raw_events.value.cast('string'),
#                           add_money_event_schema()).alias('json')) \
#         .select('raw_event', 'timestamp', 'json.*')
#
#     guild_membership = raw_events \
#         .filter(is_guild_member(raw_events.value.cast('string'))) \
#         .select(raw_events.value.cast('string').alias('raw_event'),
#                 raw_events.timestamp.cast('string'),
#                 from_json(raw_events.value.cast('string'),
#                           guild_membership_event_schema()).alias('json')) \
#         .select('raw_event', 'timestamp', 'json.*')
#
#     cancel_membership = raw_events \
#         .filter(is_cancel_member(raw_events.value.cast('string'))) \
#         .select(raw_events.value.cast('string').alias('raw_event'),
#                 raw_events.timestamp.cast('string'),
#                 from_json(raw_events.value.cast('string'),
#                           cancel_membership_event_schema()).alias('json')) \
#         .select('raw_event', 'timestamp', 'json.*')
#
#     messages2 = raw_events \
#         .filter(is_message(raw_events.value.cast('string'))) \
#         .select(raw_events.value.cast('string').alias('raw_event'),
#                 raw_events.timestamp.cast('string'),
#                 from_json(raw_events.value.cast('string'),
#                           message_event_schema()).alias('json')) \
#         .select('raw_event', 'timestamp', 'json.*')
#
#     transactions = raw_events \
#         .filter(is_transaction(raw_events.value.cast('string'))) \
#         .select(raw_events.value.cast('string').alias('raw_event'),
#                 raw_events.timestamp.cast('string'),
#                 from_json(raw_events.value.cast('string'),
#                           transaction_event_schema()).alias('json')) \
#         .select('raw_event', 'timestamp', 'json.*')
#
#     sink_purchases = purchases \
#         .writeStream \
#         .format("parquet") \
#         .option("checkpointLocation", "/tmp/checkpoints_for_purchases") \
#         .option("path", "/tmp/purchases") \
#         .trigger(processingTime="120 seconds") \
#         .start()
#
#     sink_add_money = add_money \
#         .writeStream \
#         .format("parquet") \
#         .option("checkpointLocation", "/tmp/checkpoints_for_add_money") \
#         .option("path", "/tmp/add_money") \
#         .trigger(processingTime="120 seconds") \
#         .start()
#
#     sink_guild_membership = guild_membership \
#         .writeStream \
#         .format("parquet") \
#         .option("checkpointLocation", "/tmp/checkpoints_for_guild_membership") \
#         .option("path", "/tmp/guild_membership") \
#         .trigger(processingTime="120 seconds") \
#         .start()
#
#     sink_cancel_membership = cancel_membership \
#         .writeStream \
#         .format("parquet") \
#         .option("checkpointLocation", "/tmp/checkpoints_for_cancel_membership") \
#         .option("path", "/tmp/cancel_membership") \
#         .trigger(processingTime="120 seconds") \
#         .start()
#
#     sink_messages2 = messages2 \
#         .writeStream \
#         .format("parquet") \
#         .option("checkpointLocation", "/tmp/checkpoints_for_messages2") \
#         .option("path", "/tmp/messages2") \
#         .trigger(processingTime="120 seconds") \
#         .start()
#
#     sink_transactions = transactions\
#         .writeStream \
#         .format("parquet") \
#         .option("checkpointLocation", "/tmp/checkpoints_for_transactions") \
#         .option("path", "/tmp/transactions") \
#         .trigger(processingTime="120 seconds") \
#         .start()
#
#     sink_purchases.awaitTermination()
#     sink_add_money.awaitTermination()
#     sink_guild_membership.awaitTermination()
#     sink_cancel_membership.awaitTermination()
#     #sink_messages.awaitTermination()
#     sink_messages2.awaitTermination()
#     sink_transactions.awaitTermination()
#
# if __name__ == "__main__":
#     main()

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Transactions
#
# The following user actions are tracked: addition of money, individual purchases.
#
# This information is combined to enable presentation of all transactions and current balance for all as well as each individual user.
#
#
# ##### Purchases

# %%
purchases = spark.read.parquet('/tmp/purchases')
purchases.registerTempTable('purchases')

# %%
spark.sql('select * from purchases').toPandas().head(1000)
# Out:
#                                             raw_event  \
# 0   {"event_type": "purchase_sword", "amount": "-1...
# 1   {"event_type": "purchase_sword", "amount": "-1...
# 2   {"event_type": "purchase_knife", "amount": "-1...
# 3   {"event_type": "purchase_knife", "amount": "-1...
# 4   {"event_type": "purchase_knife", "amount": "-1...
# 5   {"event_type": "purchase_knife", "amount": "-1...
# 6   {"event_type": "purchase_knife", "amount": "-1...
# 7   {"event_type": "purchase_knife", "amount": "-1...
# 8   {"event_type": "purchase_knife", "amount": "-1...
# 9   {"event_type": "purchase_knife", "amount": "-1...
# 10  {"event_type": "purchase_knife", "amount": "-1...
# 11  {"event_type": "purchase_knife", "amount": "-1...
# 12  {"event_type": "purchase_knife", "amount": "-1...
# 13  {"event_type": "purchase_knife", "amount": "-1...
# 14  {"event_type": "purchase_knife", "amount": "-1...
# 15  {"event_type": "purchase_knife", "amount": "-1...
# 16  {"event_type": "purchase_knife", "amount": "-1...
#
#                   timestamp Accept               Host       User-Agent  \
# 0   2019-08-09 20:49:21.542    */*  oski.berkeley.edu  ApacheBench/2.3
# 1   2019-08-09 20:49:21.546    */*  oski.berkeley.edu  ApacheBench/2.3
# 2   2019-08-09 20:49:29.191    */*  oski.berkeley.edu  ApacheBench/2.3
# 3   2019-08-09 20:49:29.195    */*  oski.berkeley.edu  ApacheBench/2.3
# 4     2019-08-09 20:49:29.2    */*  oski.berkeley.edu  ApacheBench/2.3
# 5   2019-08-09 20:49:29.203    */*  oski.berkeley.edu  ApacheBench/2.3
# 6   2019-08-09 20:49:29.213    */*  oski.berkeley.edu  ApacheBench/2.3
# 7   2019-08-09 20:49:29.224    */*  oski.berkeley.edu  ApacheBench/2.3
# 8   2019-08-09 20:49:29.226    */*  oski.berkeley.edu  ApacheBench/2.3
# 9   2019-08-09 20:49:29.231    */*  oski.berkeley.edu  ApacheBench/2.3
# 10  2019-08-09 20:49:29.233    */*  oski.berkeley.edu  ApacheBench/2.3
# 11  2019-08-09 20:49:29.237    */*  oski.berkeley.edu  ApacheBench/2.3
# 12  2019-08-09 20:49:29.239    */*  oski.berkeley.edu  ApacheBench/2.3
# 13  2019-08-09 20:49:29.241    */*  oski.berkeley.edu  ApacheBench/2.3
# 14  2019-08-09 20:49:29.244    */*  oski.berkeley.edu  ApacheBench/2.3
# 15  2019-08-09 20:49:29.254    */*  oski.berkeley.edu  ApacheBench/2.3
# 16  2019-08-09 20:49:29.263    */*  oski.berkeley.edu  ApacheBench/2.3
#
#         event_type amount  description
# 0   purchase_sword    -10  Great Sword
# 1   purchase_sword    -10  Great Sword
# 2   purchase_knife    -10         None
# 3   purchase_knife    -10         None
# 4   purchase_knife    -10         None
# 5   purchase_knife    -10         None
# 6   purchase_knife    -10         None
# 7   purchase_knife    -10         None
# 8   purchase_knife    -10         None
# 9   purchase_knife    -10         None
# 10  purchase_knife    -10         None
# 11  purchase_knife    -10         None
# 12  purchase_knife    -10         None
# 13  purchase_knife    -10         None
# 14  purchase_knife    -10         None
# 15  purchase_knife    -10         None
# 16  purchase_knife    -10         None

# %% [markdown]
# It is easy to count the total number of purchases made by all players. Here we can see that knives seem to be far more popular than swords. Perhaps this means we should offer incentives for players to buy knives!

# %%
spark.sql('select event_type, count(event_type) from purchases group by event_type').toPandas().head(1000)
# Out:
#        event_type  count(event_type)
# 0  purchase_sword                  2
# 1  purchase_knife                 15

# %% [markdown]
# The data contains host information, it can be used to analyse buying behavior of individual users. In the example below oski user has bought all the knives and 2 of the swords in preparation for a raid, indicating that oski is a power spender and should be retained at all costs.

# %%
spark.sql('select event_type, count(event_type) from purchases where host = "oski.berkeley.edu" group by event_type ').toPandas().head(1000)
# Out:
#        event_type  count(event_type)
# 0  purchase_sword                  2
# 1  purchase_knife                 15

# %% [markdown]
# ##### Add Money
#
# All data related users adding money to their account is captured in money table.

# %%
import pyspark.sql.types as types
import pyspark.sql.functions as fn

money = spark.read.parquet('/tmp/add_money')
money = money.withColumn("amount_int", money["amount"].cast(types.IntegerType()))
money.registerTempTable('add_money')

# %%
spark.sql('select * from add_money').toPandas().head(1000)
# Out:
#                                              raw_event  \
# 0    {"event_type": "add_money", "amount": "5", "Ac...
# 1    {"event_type": "add_money", "amount": "5", "Ac...
# 2    {"event_type": "add_money", "amount": "5", "Ac...
# 3    {"event_type": "add_money", "amount": "5", "Ac...
# 4    {"event_type": "add_money", "amount": "5", "Ac...
# 5    {"event_type": "add_money", "amount": "5", "Ac...
# 6    {"event_type": "add_money", "amount": "5", "Ac...
# 7    {"event_type": "add_money", "amount": "5", "Ac...
# 8    {"event_type": "add_money", "amount": "5", "Ac...
# 9    {"event_type": "add_money", "amount": "5", "Ac...
# 10   {"event_type": "add_money", "amount": "10", "A...
# 11   {"event_type": "add_money", "amount": "10", "A...
# 12   {"event_type": "add_money", "amount": "10", "A...
# 13   {"event_type": "add_money", "amount": "10", "A...
# 14   {"event_type": "add_money", "amount": "10", "A...
# 15   {"event_type": "add_money", "amount": "10", "A...
# 16   {"event_type": "add_money", "amount": "10", "A...
# 17   {"event_type": "add_money", "amount": "10", "A...
# 18   {"event_type": "add_money", "amount": "10", "A...
# 19   {"event_type": "add_money", "amount": "10", "A...
# 20   {"event_type": "add_money", "amount": "100", "...
# 21   {"event_type": "add_money", "amount": "100", "...
# 22   {"event_type": "add_money", "amount": "100", "...
# 23   {"event_type": "add_money", "amount": "100", "...
# 24   {"event_type": "add_money", "amount": "100", "...
# 25   {"event_type": "add_money", "amount": "100", "...
# 26   {"event_type": "add_money", "amount": "100", "...
# 27   {"event_type": "add_money", "amount": "100", "...
# 28   {"event_type": "add_money", "amount": "100", "...
# 29   {"event_type": "add_money", "amount": "100", "...
# ..                                                 ...
# 91   {"event_type": "add_money", "amount": "100", "...
# 92   {"event_type": "add_money", "amount": "100", "...
# 93   {"event_type": "add_money", "amount": "100", "...
# 94   {"event_type": "add_money", "amount": "100", "...
# 95   {"event_type": "add_money", "amount": "100", "...
# 96   {"event_type": "add_money", "amount": "100", "...
# 97   {"event_type": "add_money", "amount": "100", "...
# 98   {"event_type": "add_money", "amount": "100", "...
# 99   {"event_type": "add_money", "amount": "100", "...
# 100  {"event_type": "add_money", "amount": "100", "...
# 101  {"event_type": "add_money", "amount": "100", "...
# 102  {"event_type": "add_money", "amount": "100", "...
# 103  {"event_type": "add_money", "amount": "100", "...
# 104  {"event_type": "add_money", "amount": "100", "...
# 105  {"event_type": "add_money", "amount": "100", "...
# 106  {"event_type": "add_money", "amount": "100", "...
# 107  {"event_type": "add_money", "amount": "100", "...
# 108  {"event_type": "add_money", "amount": "100", "...
# 109  {"event_type": "add_money", "amount": "100", "...
# 110  {"event_type": "add_money", "amount": "100", "...
# 111  {"event_type": "add_money", "amount": "100", "...
# 112  {"event_type": "add_money", "amount": "100", "...
# 113  {"event_type": "add_money", "amount": "100", "...
# 114  {"event_type": "add_money", "amount": "100", "...
# 115  {"event_type": "add_money", "amount": "100", "...
# 116  {"event_type": "add_money", "amount": "100", "...
# 117  {"event_type": "add_money", "amount": "100", "...
# 118  {"event_type": "add_money", "amount": "100", "...
# 119  {"event_type": "add_money", "amount": "100", "...
# 120  {"event_type": "add_money", "amount": "1", "Ac...
#
#                    timestamp Accept               Host       User-Agent  \
# 0    2019-08-09 20:48:57.599    */*          localhost  ApacheBench/2.3
# 1    2019-08-09 20:48:57.606    */*          localhost  ApacheBench/2.3
# 2    2019-08-09 20:48:57.615    */*          localhost  ApacheBench/2.3
# 3    2019-08-09 20:48:57.631    */*          localhost  ApacheBench/2.3
# 4    2019-08-09 20:48:57.647    */*          localhost  ApacheBench/2.3
# 5    2019-08-09 20:48:57.649    */*          localhost  ApacheBench/2.3
# 6    2019-08-09 20:48:57.654    */*          localhost  ApacheBench/2.3
# 7    2019-08-09 20:48:57.656    */*          localhost  ApacheBench/2.3
# 8     2019-08-09 20:48:57.66    */*          localhost  ApacheBench/2.3
# 9    2019-08-09 20:48:57.662    */*          localhost  ApacheBench/2.3
# 10   2019-08-09 20:49:07.269    */*          localhost  ApacheBench/2.3
# 11   2019-08-09 20:49:07.274    */*          localhost  ApacheBench/2.3
# 12   2019-08-09 20:49:07.279    */*          localhost  ApacheBench/2.3
# 13   2019-08-09 20:49:07.285    */*          localhost  ApacheBench/2.3
# 14   2019-08-09 20:49:07.289    */*          localhost  ApacheBench/2.3
# 15   2019-08-09 20:49:07.292    */*          localhost  ApacheBench/2.3
# 16   2019-08-09 20:49:07.296    */*          localhost  ApacheBench/2.3
# 17     2019-08-09 20:49:07.3    */*          localhost  ApacheBench/2.3
# 18   2019-08-09 20:49:07.303    */*          localhost  ApacheBench/2.3
# 19   2019-08-09 20:49:07.315    */*          localhost  ApacheBench/2.3
# 20   2019-08-09 20:49:38.196    */*  oski.berkeley.edu  ApacheBench/2.3
# 21   2019-08-09 20:49:38.204    */*  oski.berkeley.edu  ApacheBench/2.3
# 22   2019-08-09 20:49:38.215    */*  oski.berkeley.edu  ApacheBench/2.3
# 23   2019-08-09 20:49:38.229    */*  oski.berkeley.edu  ApacheBench/2.3
# 24   2019-08-09 20:49:38.233    */*  oski.berkeley.edu  ApacheBench/2.3
# 25    2019-08-09 20:49:38.24    */*  oski.berkeley.edu  ApacheBench/2.3
# 26   2019-08-09 20:49:38.248    */*  oski.berkeley.edu  ApacheBench/2.3
# 27   2019-08-09 20:49:38.259    */*  oski.berkeley.edu  ApacheBench/2.3
# 28   2019-08-09 20:49:38.264    */*  oski.berkeley.edu  ApacheBench/2.3
# 29   2019-08-09 20:49:38.275    */*  oski.berkeley.edu  ApacheBench/2.3
# ..                       ...    ...                ...              ...
# 91   2019-08-09 20:49:38.622    */*  oski.berkeley.edu  ApacheBench/2.3
# 92   2019-08-09 20:49:38.625    */*  oski.berkeley.edu  ApacheBench/2.3
# 93   2019-08-09 20:49:38.629    */*  oski.berkeley.edu  ApacheBench/2.3
# 94   2019-08-09 20:49:38.632    */*  oski.berkeley.edu  ApacheBench/2.3
# 95   2019-08-09 20:49:38.636    */*  oski.berkeley.edu  ApacheBench/2.3
# 96   2019-08-09 20:49:38.639    */*  oski.berkeley.edu  ApacheBench/2.3
# 97   2019-08-09 20:49:38.641    */*  oski.berkeley.edu  ApacheBench/2.3
# 98   2019-08-09 20:49:38.644    */*  oski.berkeley.edu  ApacheBench/2.3
# 99   2019-08-09 20:49:38.649    */*  oski.berkeley.edu  ApacheBench/2.3
# 100  2019-08-09 20:49:38.654    */*  oski.berkeley.edu  ApacheBench/2.3
# 101  2019-08-09 20:49:38.657    */*  oski.berkeley.edu  ApacheBench/2.3
# 102   2019-08-09 20:49:38.66    */*  oski.berkeley.edu  ApacheBench/2.3
# 103  2019-08-09 20:49:38.664    */*  oski.berkeley.edu  ApacheBench/2.3
# 104  2019-08-09 20:49:38.666    */*  oski.berkeley.edu  ApacheBench/2.3
# 105  2019-08-09 20:49:38.677    */*  oski.berkeley.edu  ApacheBench/2.3
# 106  2019-08-09 20:49:38.685    */*  oski.berkeley.edu  ApacheBench/2.3
# 107   2019-08-09 20:49:38.69    */*  oski.berkeley.edu  ApacheBench/2.3
# 108  2019-08-09 20:49:38.696    */*  oski.berkeley.edu  ApacheBench/2.3
# 109  2019-08-09 20:49:38.702    */*  oski.berkeley.edu  ApacheBench/2.3
# 110   2019-08-09 20:49:38.71    */*  oski.berkeley.edu  ApacheBench/2.3
# 111  2019-08-09 20:49:38.715    */*  oski.berkeley.edu  ApacheBench/2.3
# 112  2019-08-09 20:49:38.721    */*  oski.berkeley.edu  ApacheBench/2.3
# 113  2019-08-09 20:49:38.727    */*  oski.berkeley.edu  ApacheBench/2.3
# 114  2019-08-09 20:49:38.742    */*  oski.berkeley.edu  ApacheBench/2.3
# 115  2019-08-09 20:49:38.746    */*  oski.berkeley.edu  ApacheBench/2.3
# 116  2019-08-09 20:49:38.753    */*  oski.berkeley.edu  ApacheBench/2.3
# 117  2019-08-09 20:49:38.759    */*  oski.berkeley.edu  ApacheBench/2.3
# 118  2019-08-09 20:49:38.766    */*  oski.berkeley.edu  ApacheBench/2.3
# 119  2019-08-09 20:49:38.772    */*  oski.berkeley.edu  ApacheBench/2.3
# 120  2019-08-09 20:49:56.725    */*  tree.stanfurd.edu  ApacheBench/2.3
#
#     event_type amount description  amount_int
# 0    add_money      5       money           5
# 1    add_money      5       money           5
# 2    add_money      5       money           5
# 3    add_money      5       money           5
# 4    add_money      5       money           5
# 5    add_money      5       money           5
# 6    add_money      5       money           5
# 7    add_money      5       money           5
# 8    add_money      5       money           5
# 9    add_money      5       money           5
# 10   add_money     10       money          10
# 11   add_money     10       money          10
# 12   add_money     10       money          10
# 13   add_money     10       money          10
# 14   add_money     10       money          10
# 15   add_money     10       money          10
# 16   add_money     10       money          10
# 17   add_money     10       money          10
# 18   add_money     10       money          10
# 19   add_money     10       money          10
# 20   add_money    100       money         100
# 21   add_money    100       money         100
# 22   add_money    100       money         100
# 23   add_money    100       money         100
# 24   add_money    100       money         100
# 25   add_money    100       money         100
# 26   add_money    100       money         100
# 27   add_money    100       money         100
# 28   add_money    100       money         100
# 29   add_money    100       money         100
# ..         ...    ...         ...         ...
# 91   add_money    100       money         100
# 92   add_money    100       money         100
# 93   add_money    100       money         100
# 94   add_money    100       money         100
# 95   add_money    100       money         100
# 96   add_money    100       money         100
# 97   add_money    100       money         100
# 98   add_money    100       money         100
# 99   add_money    100       money         100
# 100  add_money    100       money         100
# 101  add_money    100       money         100
# 102  add_money    100       money         100
# 103  add_money    100       money         100
# 104  add_money    100       money         100
# 105  add_money    100       money         100
# 106  add_money    100       money         100
# 107  add_money    100       money         100
# 108  add_money    100       money         100
# 109  add_money    100       money         100
# 110  add_money    100       money         100
# 111  add_money    100       money         100
# 112  add_money    100       money         100
# 113  add_money    100       money         100
# 114  add_money    100       money         100
# 115  add_money    100       money         100
# 116  add_money    100       money         100
# 117  add_money    100       money         100
# 118  add_money    100       money         100
# 119  add_money    100       money         100
# 120  add_money      1       money           1
#
# [121 rows x 9 columns]

# %% [markdown]
# We can break down the spending habits per user, and we immediately see that oski alone has spent 10k on the game analysed, adding \$100 to their account 100 times.
#
# This further reinforces the idea that oski is an invested player that we should keep.

# %%
spark.sql('select Host, sum(amount_int), avg(amount_int), count(amount_int)  from add_money group by Host ').toPandas()
# Out:
#                 Host  sum(amount_int)  avg(amount_int)  count(amount_int)
# 0          localhost              150              7.5                 20
# 1  oski.berkeley.edu            10000            100.0                100
# 2  tree.stanfurd.edu                1              1.0                  1

# %% [markdown]
# ##### Transactions
#
# All data related to addition of money and purchases is combined in money table. This enables easy analysis of all user transactions and their current balance.

# %%
transactions = spark.read.parquet('/tmp/transactions')
transactions = transactions.withColumn("amount_int", transactions["amount"].cast(types.IntegerType()))
transactions.registerTempTable('transactions')

# %%
spark.sql('select * from transactions where Host = "oski.berkeley.edu"').toPandas().head(1000)
# Out:
#                                              raw_event  \
# 0    {"event_type": "purchase_sword", "amount": "-1...
# 1    {"event_type": "purchase_sword", "amount": "-1...
# 2    {"event_type": "purchase_knife", "amount": "-1...
# 3    {"event_type": "purchase_knife", "amount": "-1...
# 4    {"event_type": "purchase_knife", "amount": "-1...
# 5    {"event_type": "purchase_knife", "amount": "-1...
# 6    {"event_type": "purchase_knife", "amount": "-1...
# 7    {"event_type": "purchase_knife", "amount": "-1...
# 8    {"event_type": "purchase_knife", "amount": "-1...
# 9    {"event_type": "purchase_knife", "amount": "-1...
# 10   {"event_type": "purchase_knife", "amount": "-1...
# 11   {"event_type": "purchase_knife", "amount": "-1...
# 12   {"event_type": "purchase_knife", "amount": "-1...
# 13   {"event_type": "purchase_knife", "amount": "-1...
# 14   {"event_type": "purchase_knife", "amount": "-1...
# 15   {"event_type": "purchase_knife", "amount": "-1...
# 16   {"event_type": "purchase_knife", "amount": "-1...
# 17   {"event_type": "add_money", "amount": "100", "...
# 18   {"event_type": "add_money", "amount": "100", "...
# 19   {"event_type": "add_money", "amount": "100", "...
# 20   {"event_type": "add_money", "amount": "100", "...
# 21   {"event_type": "add_money", "amount": "100", "...
# 22   {"event_type": "add_money", "amount": "100", "...
# 23   {"event_type": "add_money", "amount": "100", "...
# 24   {"event_type": "add_money", "amount": "100", "...
# 25   {"event_type": "add_money", "amount": "100", "...
# 26   {"event_type": "add_money", "amount": "100", "...
# 27   {"event_type": "add_money", "amount": "100", "...
# 28   {"event_type": "add_money", "amount": "100", "...
# 29   {"event_type": "add_money", "amount": "100", "...
# ..                                                 ...
# 87   {"event_type": "add_money", "amount": "100", "...
# 88   {"event_type": "add_money", "amount": "100", "...
# 89   {"event_type": "add_money", "amount": "100", "...
# 90   {"event_type": "add_money", "amount": "100", "...
# 91   {"event_type": "add_money", "amount": "100", "...
# 92   {"event_type": "add_money", "amount": "100", "...
# 93   {"event_type": "add_money", "amount": "100", "...
# 94   {"event_type": "add_money", "amount": "100", "...
# 95   {"event_type": "add_money", "amount": "100", "...
# 96   {"event_type": "add_money", "amount": "100", "...
# 97   {"event_type": "add_money", "amount": "100", "...
# 98   {"event_type": "add_money", "amount": "100", "...
# 99   {"event_type": "add_money", "amount": "100", "...
# 100  {"event_type": "add_money", "amount": "100", "...
# 101  {"event_type": "add_money", "amount": "100", "...
# 102  {"event_type": "add_money", "amount": "100", "...
# 103  {"event_type": "add_money", "amount": "100", "...
# 104  {"event_type": "add_money", "amount": "100", "...
# 105  {"event_type": "add_money", "amount": "100", "...
# 106  {"event_type": "add_money", "amount": "100", "...
# 107  {"event_type": "add_money", "amount": "100", "...
# 108  {"event_type": "add_money", "amount": "100", "...
# 109  {"event_type": "add_money", "amount": "100", "...
# 110  {"event_type": "add_money", "amount": "100", "...
# 111  {"event_type": "add_money", "amount": "100", "...
# 112  {"event_type": "add_money", "amount": "100", "...
# 113  {"event_type": "add_money", "amount": "100", "...
# 114  {"event_type": "add_money", "amount": "100", "...
# 115  {"event_type": "add_money", "amount": "100", "...
# 116  {"event_type": "add_money", "amount": "100", "...
#
#                    timestamp Accept               Host       User-Agent  \
# 0    2019-08-09 20:49:21.542    */*  oski.berkeley.edu  ApacheBench/2.3
# 1    2019-08-09 20:49:21.546    */*  oski.berkeley.edu  ApacheBench/2.3
# 2    2019-08-09 20:49:29.191    */*  oski.berkeley.edu  ApacheBench/2.3
# 3    2019-08-09 20:49:29.195    */*  oski.berkeley.edu  ApacheBench/2.3
# 4      2019-08-09 20:49:29.2    */*  oski.berkeley.edu  ApacheBench/2.3
# 5    2019-08-09 20:49:29.203    */*  oski.berkeley.edu  ApacheBench/2.3
# 6    2019-08-09 20:49:29.213    */*  oski.berkeley.edu  ApacheBench/2.3
# 7    2019-08-09 20:49:29.224    */*  oski.berkeley.edu  ApacheBench/2.3
# 8    2019-08-09 20:49:29.226    */*  oski.berkeley.edu  ApacheBench/2.3
# 9    2019-08-09 20:49:29.231    */*  oski.berkeley.edu  ApacheBench/2.3
# 10   2019-08-09 20:49:29.233    */*  oski.berkeley.edu  ApacheBench/2.3
# 11   2019-08-09 20:49:29.237    */*  oski.berkeley.edu  ApacheBench/2.3
# 12   2019-08-09 20:49:29.239    */*  oski.berkeley.edu  ApacheBench/2.3
# 13   2019-08-09 20:49:29.241    */*  oski.berkeley.edu  ApacheBench/2.3
# 14   2019-08-09 20:49:29.244    */*  oski.berkeley.edu  ApacheBench/2.3
# 15   2019-08-09 20:49:29.254    */*  oski.berkeley.edu  ApacheBench/2.3
# 16   2019-08-09 20:49:29.263    */*  oski.berkeley.edu  ApacheBench/2.3
# 17   2019-08-09 20:49:38.196    */*  oski.berkeley.edu  ApacheBench/2.3
# 18   2019-08-09 20:49:38.204    */*  oski.berkeley.edu  ApacheBench/2.3
# 19   2019-08-09 20:49:38.215    */*  oski.berkeley.edu  ApacheBench/2.3
# 20   2019-08-09 20:49:38.229    */*  oski.berkeley.edu  ApacheBench/2.3
# 21   2019-08-09 20:49:38.233    */*  oski.berkeley.edu  ApacheBench/2.3
# 22    2019-08-09 20:49:38.24    */*  oski.berkeley.edu  ApacheBench/2.3
# 23   2019-08-09 20:49:38.248    */*  oski.berkeley.edu  ApacheBench/2.3
# 24   2019-08-09 20:49:38.259    */*  oski.berkeley.edu  ApacheBench/2.3
# 25   2019-08-09 20:49:38.264    */*  oski.berkeley.edu  ApacheBench/2.3
# 26   2019-08-09 20:49:38.275    */*  oski.berkeley.edu  ApacheBench/2.3
# 27   2019-08-09 20:49:38.285    */*  oski.berkeley.edu  ApacheBench/2.3
# 28   2019-08-09 20:49:38.292    */*  oski.berkeley.edu  ApacheBench/2.3
# 29   2019-08-09 20:49:38.304    */*  oski.berkeley.edu  ApacheBench/2.3
# ..                       ...    ...                ...              ...
# 87   2019-08-09 20:49:38.619    */*  oski.berkeley.edu  ApacheBench/2.3
# 88   2019-08-09 20:49:38.622    */*  oski.berkeley.edu  ApacheBench/2.3
# 89   2019-08-09 20:49:38.625    */*  oski.berkeley.edu  ApacheBench/2.3
# 90   2019-08-09 20:49:38.629    */*  oski.berkeley.edu  ApacheBench/2.3
# 91   2019-08-09 20:49:38.632    */*  oski.berkeley.edu  ApacheBench/2.3
# 92   2019-08-09 20:49:38.636    */*  oski.berkeley.edu  ApacheBench/2.3
# 93   2019-08-09 20:49:38.639    */*  oski.berkeley.edu  ApacheBench/2.3
# 94   2019-08-09 20:49:38.641    */*  oski.berkeley.edu  ApacheBench/2.3
# 95   2019-08-09 20:49:38.644    */*  oski.berkeley.edu  ApacheBench/2.3
# 96   2019-08-09 20:49:38.649    */*  oski.berkeley.edu  ApacheBench/2.3
# 97   2019-08-09 20:49:38.654    */*  oski.berkeley.edu  ApacheBench/2.3
# 98   2019-08-09 20:49:38.657    */*  oski.berkeley.edu  ApacheBench/2.3
# 99    2019-08-09 20:49:38.66    */*  oski.berkeley.edu  ApacheBench/2.3
# 100  2019-08-09 20:49:38.664    */*  oski.berkeley.edu  ApacheBench/2.3
# 101  2019-08-09 20:49:38.666    */*  oski.berkeley.edu  ApacheBench/2.3
# 102  2019-08-09 20:49:38.677    */*  oski.berkeley.edu  ApacheBench/2.3
# 103  2019-08-09 20:49:38.685    */*  oski.berkeley.edu  ApacheBench/2.3
# 104   2019-08-09 20:49:38.69    */*  oski.berkeley.edu  ApacheBench/2.3
# 105  2019-08-09 20:49:38.696    */*  oski.berkeley.edu  ApacheBench/2.3
# 106  2019-08-09 20:49:38.702    */*  oski.berkeley.edu  ApacheBench/2.3
# 107   2019-08-09 20:49:38.71    */*  oski.berkeley.edu  ApacheBench/2.3
# 108  2019-08-09 20:49:38.715    */*  oski.berkeley.edu  ApacheBench/2.3
# 109  2019-08-09 20:49:38.721    */*  oski.berkeley.edu  ApacheBench/2.3
# 110  2019-08-09 20:49:38.727    */*  oski.berkeley.edu  ApacheBench/2.3
# 111  2019-08-09 20:49:38.742    */*  oski.berkeley.edu  ApacheBench/2.3
# 112  2019-08-09 20:49:38.746    */*  oski.berkeley.edu  ApacheBench/2.3
# 113  2019-08-09 20:49:38.753    */*  oski.berkeley.edu  ApacheBench/2.3
# 114  2019-08-09 20:49:38.759    */*  oski.berkeley.edu  ApacheBench/2.3
# 115  2019-08-09 20:49:38.766    */*  oski.berkeley.edu  ApacheBench/2.3
# 116  2019-08-09 20:49:38.772    */*  oski.berkeley.edu  ApacheBench/2.3
#
#          event_type amount  description  amount_int
# 0    purchase_sword    -10  Great Sword         -10
# 1    purchase_sword    -10  Great Sword         -10
# 2    purchase_knife    -10         None         -10
# 3    purchase_knife    -10         None         -10
# 4    purchase_knife    -10         None         -10
# 5    purchase_knife    -10         None         -10
# 6    purchase_knife    -10         None         -10
# 7    purchase_knife    -10         None         -10
# 8    purchase_knife    -10         None         -10
# 9    purchase_knife    -10         None         -10
# 10   purchase_knife    -10         None         -10
# 11   purchase_knife    -10         None         -10
# 12   purchase_knife    -10         None         -10
# 13   purchase_knife    -10         None         -10
# 14   purchase_knife    -10         None         -10
# 15   purchase_knife    -10         None         -10
# 16   purchase_knife    -10         None         -10
# 17        add_money    100        money         100
# 18        add_money    100        money         100
# 19        add_money    100        money         100
# 20        add_money    100        money         100
# 21        add_money    100        money         100
# 22        add_money    100        money         100
# 23        add_money    100        money         100
# 24        add_money    100        money         100
# 25        add_money    100        money         100
# 26        add_money    100        money         100
# 27        add_money    100        money         100
# 28        add_money    100        money         100
# 29        add_money    100        money         100
# ..              ...    ...          ...         ...
# 87        add_money    100        money         100
# 88        add_money    100        money         100
# 89        add_money    100        money         100
# 90        add_money    100        money         100
# 91        add_money    100        money         100
# 92        add_money    100        money         100
# 93        add_money    100        money         100
# 94        add_money    100        money         100
# 95        add_money    100        money         100
# 96        add_money    100        money         100
# 97        add_money    100        money         100
# 98        add_money    100        money         100
# 99        add_money    100        money         100
# 100       add_money    100        money         100
# 101       add_money    100        money         100
# 102       add_money    100        money         100
# 103       add_money    100        money         100
# 104       add_money    100        money         100
# 105       add_money    100        money         100
# 106       add_money    100        money         100
# 107       add_money    100        money         100
# 108       add_money    100        money         100
# 109       add_money    100        money         100
# 110       add_money    100        money         100
# 111       add_money    100        money         100
# 112       add_money    100        money         100
# 113       add_money    100        money         100
# 114       add_money    100        money         100
# 115       add_money    100        money         100
# 116       add_money    100        money         100
#
# [117 rows x 9 columns]

# %% [markdown]
# Example: view current balance for the users

# %%
spark.sql('select Host, sum(amount_int) from transactions group by Host').toPandas().head(1000)
# Out:
#                 Host  sum(amount_int)
# 0          localhost              150
# 1  oski.berkeley.edu             9830
# 2  tree.stanfurd.edu                1

# %% [markdown]
# ### Memberships and cancellations

# %%
guild = spark.read.parquet('/tmp/guild_membership')
guild.registerTempTable('guild_membership')
cancels = spark.read.parquet('/tmp/cancel_membership')
cancels.registerTempTable('cancel_membership')

# %% [markdown]
# #### Memberships
#
# We can see that the stanford user joined the stanford guild, and the berkeley user joined the berkeley guild. This is important information to be able to see what users are connected, how and when. These insights may allow us to attract new users, build stronger connections between current players and increase our retention.

# %%
spark.sql('select * from guild_membership').toPandas()
# Out:
#                                            raw_event                timestamp  \
# 0  {"Host": "tree.stanford.edu", "User-Agent": "A...  2019-08-09 20:50:04.701
# 1  {"Host": "berkeley.edu", "User-Agent": "Apache...  2019-08-09 20:50:11.355
#
#   Accept               Host       User-Agent  event_type guild_name
# 0    */*  tree.stanford.edu  ApacheBench/2.3  join_guild   stanford
# 1    */*       berkeley.edu  ApacheBench/2.3  join_guild   berkeley

# %% [markdown]
# #### Cancellations
#
# In fact, we can see this in action. The stanford host canceled their membership not long after joining the stanford guild. Is this due to being dissatisfied? Perhaps the berkeley guild beat the stanford guild and the stanford host is changing sides? They did not leave a reason for leaving, but such user feedback is extremeley important.

# %%
spark.sql('select * from cancel_membership').toPandas()
# Out:
#                                            raw_event                timestamp  \
# 0  {"Host": "tree.stanford.edu", "cancel_reason":...  2019-08-09 20:50:29.541
#
#   Accept               Host       User-Agent         event_type cancel_reason
# 0    */*  tree.stanford.edu  ApacheBench/2.3  cancel_membership          None

# %% [markdown]
# #### Messaging (GET & POST)
#
# Finally, we can see all the messages posted by users to the message board. The only message we see currently is the admin reminding everyone that cheating is not allowed. However, activity on this message board is also important to gauge user involvement.

# %%
messages2 = spark.read.parquet('/tmp/messages2')
messages2.registerTempTable('messages2')

# %%
spark.sql('select * from messages2').toPandas()
# Out:
#                                            raw_event                timestamp  \
# 0  {"message_post": "this is a GET message", "Hos...  2019-08-09 22:11:13.056
# 1  {"Content-Length": "45", "event_type": "mensaj...  2019-08-09 22:11:17.059
#
#   Accept            Host   User-Agent event_type  \
# 0    */*  localhost:5000  curl/7.47.0    mensaje
# 1    */*  localhost:5000  curl/7.47.0    mensaje
#
#                        message_post
# 0             this is a GET message
# 1  this is a POST message - booyah!
